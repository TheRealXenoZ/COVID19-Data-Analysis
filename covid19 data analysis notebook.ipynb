# %% [markdown]
# # Welcome to Covid19 Data Analysis Notebook
# ------------------------------------------

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Task 2.1: importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
corona_dataset_csv = pd.read_csv("Datasets/covid19_Confirmed_dataset.csv")
corona_dataset_csv.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Task 2.2: Delete the useless columns

# %%
corona_dataset_csv.drop(["Lat", "Long"], axis=1, inplace=True)

# %%
corona_dataset_csv.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# ### Task 2.3: Aggregating the rows by the country

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# ### Task 2.4: Visualizing data related to a country for example China
# visualization always helps for better understanding of our data.

# %%
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["Italy"].plot()
corona_dataset_aggregated.loc["Spain"].plot()
plt.legend()

# %% [markdown]
# ### Task3: Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
corona_dataset_aggregated.loc['China'].plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc['China'][:3].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### task 3.1: caculating the first derivative of the curve

# %%
corona_dataset_aggregated.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### task 3.2: find maxmimum infection rate for China

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc['Italy'].diff().max()
# Out:
# 6557.0

# %%
corona_dataset_aggregated.loc['Spain'].diff().max()
# Out:
# 9630.0

# %% [markdown]
# ### Task 3.3: find maximum infection rate for all of the countries.

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries:
   max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['max_infection_rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %% [markdown]
# ### Task 3.4: create a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rate"])

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %% [markdown]
# ### Task4:
# - Importing the WorldHappinessReport.csv dataset
# - selecting needed columns for our analysis
# - join the datasets
# - calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1 : importing the dataset

# %%
happiness_report = pd.read_csv("Datasets/worldwide_happiness_report.csv")

# %%
happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ### Task 4.2: let's drop the useless columns

# %%
useless_cols = ["Overall rank", "Score", "Generosity", "Perceptions of corruption"]

# %%
for cols in useless_cols:
    happiness_report.drop([cols], axis=1, inplace=True)
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ### Task 4.3: changing the indices of the dataframe

# %%
happiness_report.set_index("Country or region", inplace=True)
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# ### Task4.4: now let's join two dataset we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %% [markdown]
# #### wolrd happiness report Dataset :

# %%
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
data = corona_data.join(happiness_report, how="inner")
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ### Task 4.5: correlation matrix

# %%
data.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.078196
# ...

# %% [markdown]
# ### Task 5: Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ### Task 5.1: Plotting GDP vs maximum Infection rate

# %%
x = data['GDP per capita']
y = data['max_infection_rate']
sns.scatterplot(x=x, y=np.log(y))
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
sns.regplot(x, np.log(y))
# Out:
# C:\Users\DJ-X\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infection_rate'>

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x = data['Social support']
y = data['max_infection_rate']
sns.scatterplot(x, np.log(y))
# Out:
# C:\Users\DJ-X\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Social support', ylabel='max_infection_rate'>

# %%
sns.regplot(x, np.log(y))
# Out:
# C:\Users\DJ-X\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Social support', ylabel='max_infection_rate'>

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data['Healthy life expectancy']
y = data['max_infection_rate']
sns.scatterplot(x, np.log(y))
# Out:
# C:\Users\DJ-X\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_infection_rate'>

# %%
sns.regplot(x, np.log(y))
# Out:
# C:\Users\DJ-X\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_infection_rate'>

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data['Freedom to make life choices']
y = data['max_infection_rate']
sns.scatterplot(x, np.log(y))
# Out:
# C:\Users\DJ-X\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max_infection_rate'>

# %%
sns.regplot(x, np.log(y))
# Out:
# C:\Users\DJ-X\AppData\Roaming\Python\Python39\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max_infection_rate'>

# %% [markdown]
# ### Importing the C19 Deaths Dataset

# %%
corona_deaths = pd.read_csv("Datasets/covid19_deaths_dataset.csv")
corona_deaths.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
corona_deaths.drop(['Lat', 'Long'], axis=1, inplace=True)
corona_deaths.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
corona_deaths_aggregated = corona_deaths.groupby("Country/Region").sum()
corona_deaths_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       36       40       42
# Albania               0        0        0  ...       26       27       27
# Algeria               0        0        0  ...      392      402      407
# Andorra               0        0        0  ...       37       37       37
# ...

# %%
corona_deaths_aggregated.loc['India'].diff().max()
max_death_rates = []
death_countries = list(corona_dataset_aggregated.index)

# %%
for country in death_countries:
    max_death_rates.append(corona_deaths_aggregated.loc[country].diff().max())
max_death_rates
# Out:
# [7.0,
#  4.0,
#  30.0,
#  4.0,
#  2.0,
#  1.0,
#  13.0,
#  3.0,
#  8.0,
#  30.0,
#  3.0,
#  3.0,
#  1.0,
#  15.0,
#  1.0,
#  5.0,
#  496.0,
#  1.0,
#  1.0,
#  0.0,
#  6.0,
#  6.0,
#  1.0,
#  493.0,
#  1.0,
#  6.0,
#  4.0,
#  2.0,
#  1.0,
#  1.0,
#  0.0,
#  20.0,
#  251.0,
#  0.0,
#  3.0,
#  13.0,
#  1290.0,
#  26.0,
#  0.0,
#  3.0,
#  5.0,
#  1.0,
#  4.0,
#  8.0,
#  6.0,
#  2.0,
#  18.0,
#  22.0,
#  2.0,
#  1.0,
#  0.0,
#  38.0,
#  208.0,
#  22.0,
#  1.0,
#  1.0,
#  0.0,
#  6.0,
#  1.0,
#  2.0,
#  0.0,
#  43.0,
#  1440.0,
#  1.0,
#  1.0,
#  1.0,
#  510.0,
#  5.0,
#  10.0,
#  0.0,
#  3.0,
#  2.0,
#  1.0,
#  2.0,
#  2.0,
#  0.0,
#  8.0,
#  23.0,
#  5.0,
#  75.0,
#  60.0,
#  158.0,
#  7.0,
#  220.0,
#  13.0,
#  919.0,
#  2.0,
#  47.0,
#  2.0,
#  5.0,
#  2.0,
#  11.0,
#  10.0,
#  4.0,
#  3.0,
#  0.0,
#  4.0,
#  2.0,
#  4.0,
#  1.0,
#  1.0,
#  6.0,
#  8.0,
#  2.0,
#  0.0,
#  1.0,
#  8.0,
#  1.0,
#  4.0,
#  1.0,
#  1.0,
#  2.0,
#  163.0,
#  10.0,
#  2.0,
#  0.0,
#  1.0,
#  12.0,
#  0.0,
# ...

# %%
corona_deaths_aggregated["max_death_rate"] = max_death_rates
corona_deaths_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       40       42       43
# Albania               0        0        0  ...       27       27       27
# Algeria               0        0        0  ...      402      407      415
# Andorra               0        0        0  ...       37       37       40
# ...

# %%
corona_death_data = pd.DataFrame(corona_deaths_aggregated['max_death_rate'])
corona_death_data.head()
# Out:
#                 max_death_rate
# Country/Region
# Afghanistan                7.0
# Albania                    4.0
# Algeria                   30.0
# Andorra                    4.0
# Angola                     2.0

# %% [markdown]
# ## Combining Death Rate data with Infection Data and Generating IFR (Infection Fatality Rate)

# %%
combined_data = data.join(corona_death_data, how='inner')
combined_data['IFR'] = ((combined_data['max_death_rate']/combined_data['max_infection_rate']) * 100)
combined_data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices  \
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283
#
#              max_death_rate        IFR
# Afghanistan             7.0   3.017241
# Albania                 4.0  11.764706
# Algeria                30.0  15.075377
# ...

# %% [markdown]
# ## Visualising Data

# %% [markdown]
# ### Plotting Infection Rate to Death Rate

# %%
x = combined_data['max_infection_rate']
y = combined_data['max_death_rate']
sns.scatterplot(x=x, y=y)
# Out:
# <AxesSubplot:xlabel='max_infection_rate', ylabel='max_death_rate'>

# %%
sns.regplot(x=x, y=y)
# Out:
# <AxesSubplot:xlabel='max_infection_rate', ylabel='max_death_rate'>

# %% [markdown]
# ### Comparing IFR% v/s GDP per capita and Freedom to make life choices

# %%
x = combined_data['GDP per capita']
y = combined_data['IFR']
sns.scatterplot(x=x, y=y)
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='IFR'>

# %%
sns.regplot(x=x, y=y)
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='IFR'>

# %%
x = combined_data['Freedom to make life choices']
y = combined_data['IFR']
sns.scatterplot(x=x, y=y)
# Out:
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='IFR'>

# %%
sns.regplot(x=x, y=y)
# Out:
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='IFR'>

# %% [markdown]
# ### We can notice that the Higher the GDP per capita and Higher Freedom to make life choices, Lower the IFR %

# %%
x = combined_data['Healthy life expectancy']
y = combined_data['IFR']
sns.scatterplot(x=x, y=y)
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='IFR'>

# %%
sns.regplot(x=x, y=y)
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='IFR'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## We can notice that, as the Happiness Index increases, the total IFR percentage of a country usually drops. This is due to the higher amount of amenities, freedom and the knowledge of the country.
